# %%
# 155. Min Stack

class MinStack:

    def __init__(self):
        self.stack = []
        self.minStack = []

    def push(self, val):
        self.stack.append(val)
        if not self.minStack:
            self.minStack.append(val)
        else:
            self.minStack.append(min(val, self.minStack[-1]))

    def pop(self):
        self.stack.pop()
        self.minStack.pop()

    def top(self):
        return self.stack[-1]

    def getMin(self):
        return self.minStack[-1]

# Your MinStack object will be instantiated and called as such:
# obj = MinStack()
# obj.push(val)
# obj.pop()
# param_3 = obj.top()
# param_4 = obj.getMin()

# %%
# 71. Simplify Path

class Solution(object):
    def simplifyPath(self, path):
        """
        :type path: str
        :rtype: str
        """
        
        stack = []
        parts = path.split('/')
        for part in parts:
            if part == '' or part == '.':
                continue

            elif part == '..':
                if stack:
                    stack.pop()

            else:
                stack.append(part)

        path = '/' + '/'.join(stack)
        print(path)
        return path

# %%
# 150. Evaluate Reverse Polish Notation

class Solution(object):
    def evalRPN(self, tokens):

        stack = []
        

        for token in tokens:

            if token in ["+", "-", "*", "/"]:

                b = stack.pop()
                a = stack.pop()

                if token == "+":
                    stack.append(a + b)

                elif token == "-":
                    stack.append(a - b)

                elif token == "*":
                    stack.append(a * b)

                else:
                    stack.append(int(a / b))
                print (a , b , stack[-1])
            else:
                stack.append(int(token))

        return stack[-1]

# %%
# 22. Generate Parentheses

class Solution:
    def generateParenthesis(self, n):
        
        stack = []
        op = []
        o_count = 0
        c_count = 0
        def gen_brackets(stack , o_count , c_count):
            if o_count == n and c_count == n:

                op.append("".join(stack))
                return 

            if o_count < n:
                stack.append("(")
                gen_brackets(stack , o_count + 1 , c_count)
                stack.pop()

            if o_count > c_count :
                stack.append(")")
                gen_brackets(stack , o_count , c_count + 1)
                stack.pop()
            

        gen_brackets(stack , o_count , c_count)
        return op
